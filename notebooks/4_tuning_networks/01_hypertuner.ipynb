# %% [markdown]
# <td>
# <a href="https://colab.research.google.com/github/raoulg/MADS-MachineLearning-course/blob/master/notebooks/4_tuning_networks/01_hypertuner.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
# </td>

# %%
import time
import numpy as np
from plotly import graph_objects as go
import matplotlib.pyplot as plt

from loguru import logger

import ray
from ray import tune

import torch
from torch import optim
from torch import nn

from pathlib import Path

# %matplotlib inline
plt.style.use('dark_background')
# import plotly.io as pio
# pio.renderers.default = 'plotly_mimetype+notebook'

import visualize
DELETE = True # to delete the tunedir at the end of the notebook
start = time.time()

# %% [markdown]
# This is a general reference notebook to explore the use of ray tuner.
# First, we define some global variables. This makes it easier to change the parameters for the full notebook at once and run everything.
#
# Set the max_epochs to something like 10 (this will take longer, but you will get better results), and experiments to 18. This way, you will have a good way to compare gridsearch with the other tuners because gridsearch will do 3 * 6 = 18 experiments.
#
# The reason I am setting this low is because i automated the testing of the notebook and it takes a long time to run all the experiments by default.

# %%
MAX_EPOCHS = 10
N_EXPERIMENTS = 18

# %% [markdown]
# # Train function and config

# %% [markdown]
# Let's define some dicts to log the results of the training.

# %%
timer = {}
best_config = {}

# %% [markdown]
# We will need a training function. This is also implemented in the mltrainer, but I put it here to show you how the details work.

# %%
def train_fn(model, trainstreamer, lossfn, optimizer, steps):
    model.train()
    train_loss: float = 0.0
    for _ in range(steps):
        x, y = next(trainstreamer)
        optimizer.zero_grad()
        yhat = model(x)
        loss = lossfn(yhat, y)
        loss.backward()
        optimizer.step()
        train_loss += loss.item()
    return train_loss

# %% [markdown]
# We validate on the validation set and return the loss.

# %%
def validate(model, validstreamer, lossfn, metric, steps):
    model.eval()
    valid_loss: float = 0.0
    acc: float = 0.0
    with torch.no_grad():
        for _ in range(steps):
            x, y = next(validstreamer)
            yhat = model(x)
            loss = lossfn(yhat, y)
            valid_loss += loss.item()
            acc += metric(y, yhat)
    acc /= steps
    return valid_loss, acc

# %% [markdown]
# Getting the data requires a bit extra care. Because we will run experiments in parallel on all the cpu's available, we well use FileLock to make sure that loading the data does not conflict.
#
# Note we import functions inside the function we will later on pass to ray. This is because ray will serialize the function and send it to the workers. If we import the functions outside the function, the workers will not have access to them.

# %%
def get_data(tune_dir):
    from filelock import FileLock
    from mads_datasets import DatasetFactoryProvider, DatasetType
    from mltrainer.preprocessors import PaddedPreprocessor
    from mads_datasets import DatasetFactoryProvider, DatasetType
    with FileLock(tune_dir / ".lock"):
        # we lock the datadir to avoid parallel instances trying to
        # access the datadir
        preprocessor = PaddedPreprocessor()
        gesturesdatasetfactory = DatasetFactoryProvider.create_factory(DatasetType.GESTURES)
        streamers = gesturesdatasetfactory.create_datastreamer(
            batchsize=32, preprocessor=preprocessor
        )
        train = streamers["train"]
        valid = streamers["valid"]
    return train, valid

# %% [markdown]
# We will use the same GRU model we used last lesson. You might improve this in a few ways (eg consider adding skip layers, conv1d, etc) but for clarity, lets keep it simple.

# %%
class GRUmodel(nn.Module):
    def __init__(
        self,
        config: dict,
    ) -> None:
        super().__init__()
        self.rnn = nn.GRU(
            input_size=config["input_size"],
            hidden_size=int(config["hidden_size"]),
            dropout=config["dropout"],
            batch_first=True,
            num_layers=int(config["num_layers"]),
        )
        self.linear = nn.Linear(int(config["hidden_size"]), config["output_size"])

    def forward(self, x):
        x, _ = self.rnn(x)
        last_step = x[:, -1, :]
        yhat = self.linear(last_step)
        return yhat

# %% [markdown]
# Now, we have all the ingredients we need to run the tuner.
# We create a function that:
# - loads the data with a lock
# - creates the model
# - trains the model
# - validates the model
# - reports the results to ray

# %%
def tune_model(config: dict):
    from mltrainer.metrics import Accuracy

    # load data
    train, valid = get_data(config["tune_dir"])
    trainsteps = len(train)
    validsteps = len(valid)
    trainstreamer = train.stream()
    validstreamer = valid.stream()

    # create model with config
    model = GRUmodel(config)
    optimizer = optim.Adam(model.parameters(), lr=0.001)
    loss_fn = torch.nn.CrossEntropyLoss()
    metric = Accuracy()

    for _ in range(config["epochs"]):
        # train and validate
        train_loss = train_fn(model, trainstreamer, loss_fn, optimizer, trainsteps)
        valid_loss, accuracy = validate(model, validstreamer, loss_fn, metric, validsteps)

        # report to ray
        ray.train.report({
            "valid_loss": valid_loss / validsteps,
            "train_loss": train_loss / trainsteps,
            "accuracy" : accuracy,
            })

# %% [markdown]
# Let's try this, to see if everything works as expected.
# Note that it typically does not make sense to use accelaration here; we will typically have 1 GPU, but 10 or 16 CPUS. We gain much more from parallelizing the experiments than we gain by running the model faster on a single GPU.

# %%
tune_dir = Path("logs/test/").resolve()

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "hidden_size": 64,
    "num_layers": 2,
    "epochs": MAX_EPOCHS,
    "tune_dir": tune_dir,
}
tune_model(config)
# Out:
# 2025-10-01 22:09:04.524 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
# 100%|██████████| 2600/2600 [00:00<00:00, 5312.90it/s]
# 100%|██████████| 651/651 [00:00<00:00, 5689.41it/s]
# /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:657: UserWarning: `report` is meant to only be called inside a function that is executed by a Tuner or Trainer. Returning `None`.
#   warnings.warn(

# %% [markdown]
# # Random search

# %% [markdown]
# Now, let's do a random search.
#
# First, we define the search space. We can specify specific values, but also distributions.
# For the hidden size, we will use randint, which will sample from a uniform distribution of integers.
# The same for the number of layers.
#
# The `tune.run` function runs the hypertuning. It will sample from the search space, and create a specific config for each experiment.

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.05,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

# %% [markdown]
# Let's test this!

# %%
tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    verbose=1,
)

timer["ray_random"] = time.time() - tic
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-10-01 22:13:31</td></tr>
# <tr><td>Running for: </td><td>00:04:02.28        </td></tr>
# <tr><td>Memory:      </td><td>9.0/16.0 GiB       </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/10 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  valid_loss</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td
/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 7351.99it/s]
# 100%|██████████| 651/651 [00:00<00:00, 7326.89it/s]
#  25%|██▍       | 640/2600 [00:00<00:00, 6397.72it/s]
#  50%|█████     | 1305/2600 [00:00<00:00, 6543.83it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 6600.29it/s]
# 100%|██████████| 651/651 [00:00<00:00, 6160.04it/s]
#  26%|██▌       | 679/2600 [00:00<00:00, 6787.68it/s]
#  56%|█████▌    | 1452/2600 [00:00<00:00, 7341.14it/s]
# (tune_model pid=29281) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=29281)   _log_deprecation_warning(
#  84%|████████▍ | 2187/2600 [00:00<00:00, 6409.11it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 6489.63it/s]
#  28%|██▊       | 729/2600 [00:00<00:00, 7270.73it/s]
#  56%|█████▌    | 1457/2600 [00:00<00:00, 6058.94it/s]
#  80%|███████▉  | 2076/2600 [00:00<00:00, 5935.29it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 6073.97it/s]
# 100%|██████████| 651/651 [00:00<00:00, 7006.92it/s]
#  15%|█▌        | 399/2600 [00:00<00:00, 3986.34it/s]
#  35%|███▍      | 901/2600 [00:00<00:00, 4592.49it/s]
#  55%|█████▍    | 1418/2600 [00:00<00:00, 4854.43it/s]
#  74%|███████▎  | 1913/2600 [00:00<00:00, 4890.84it/s]
# (tune_model pid=29284) 2025-10-01 22:09:40.033 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures [repeated 8x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# 100%|██████████| 2600/2600 [00:00<00:00, 4721.99it/s]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 16x across cluster]
# 100%|██████████| 651/651 [00:00<00:00, 5164.78it/s]
#  28%|██▊       | 722/2600 [00:00<00:00, 7208.77it/s]
#  56%|█████▌    | 1443/2600 [00:00<00:00, 5731.16it/s]
#  79%|███████▉  | 2052/2600 [00:00<00:00, 5874.28it/s]
# (tune_model pid=29284) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.05 and num_layers=1 [repeated 2x across cluster]
# (tune_model pid=29284)   warnings.warn( [repeated 2x across cluster]
# 100%|██████████| 2600/2600 [00:00<00:00, 5975.89it/s]
# 100%|██████████| 651/651 [00:00<00:00, 6146.85it/s]
# (tune_model pid=29282) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 5x across cluster]
# (tune_model pid=29282)   _log_deprecation_warning( [repeated 5x across cluster]
# (tune_model pid=29286) 2025-10-01 22:09:40.865 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
# (tune_model pid=29278) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 3x across cluster]
# (tune_model pid=29278)   _log_deprecation_warning( [repeated 3x across cluster]
# (tune_model pid=29285) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=29285)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=29286) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=29286)   _log_deprecation_warning(
# (tune_model pid=29331) 2025-10-01 22:10:00.789 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  13%|█▎        | 348/2600 [00:00<00:00, 3478.33it/s]
#  27%|██▋       | 696/2600 [00:00<00:00, 2821.91it/s]
#  38%|███▊      | 986/2600 [00:00<00:00, 2660.53it/s]
#  52%|█████▏    | 1361/2600 [00:00<00:00, 3040.55it/s]
#  64%|██████▍   | 1673/2600 [00:00<00:00, 2697.59it/s]
#  75%|███████▌  | 1952/2600 [00:00<00:00, 2516.31it/s]
#  88%|████████▊ | 2300/2600 [00:00<00:00, 2784.93it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 2820.06it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  40%|████      | 263/651 [00:00<00:00, 2626.43it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2849.43it/s]
# (tune_model pid=29331) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.05 and num_layers=1
# (tune_model pid=29331)   warnings.warn(
# (tune_model pid=29331) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=29331)   _log_deprecation_warning(
# (tune_model pid=29280) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=29280)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=29361) 2025-10-01 22:10:16.975 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
# (tune_model pid=29283) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=29283)   warnings.warn('resource_tracker: There appear to be %d '
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  11%|█▏        | 296/2600 [00:00<00:00, 2953.89it/s]
#  26%|██▌       | 680/2600 [00:00<00:00, 3473.42it/s]
#  41%|████      | 1054/2600 [00:00<00:00, 3578.69it/s]
#  54%|█████▍    | 1412/2600 [00:00<00:00, 3080.61it/s]
#  66%|██████▋   | 1729/2600 [00:00<00:00, 3059.53it/s]
#  78%|███████▊  | 2041/2600 [00:00<00:00, 2902.36it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 3171.88it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  44%|████▍     | 286/651 [00:00<00:00, 2853.58it/s]
# 100%|██████████| 651/651 [00:00<00:00, 3264.27it/s]
#  15%|█▍        | 382/2600 [00:00<00:00, 3819.28it/s]
#  29%|██▉       | 764/2600 [00:00<00:00, 3637.35it/s]
#  50%|████▉     | 1295/2600 [00:00<00:00, 4378.81it/s]
#  67%|██████▋   | 1736/2600 [00:00<00:00, 4200.35it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4130.58it/s]
#  63%|██████▎   | 407/651 [00:00<00:00, 4064.32it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4541.62it/s]
# (tune_model pid=29331) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=29331)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=29364) 2025-10-01 22:10:18.732 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
# (tune_model pid=29361) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=29361)   _log_deprecation_warning(
# (tune_model pid=29376) 2025-10-01 22:10:28.130 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
# (tune_model pid=29281) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=29281)   warnings.warn('resource_tracker: There appear to be %d '
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  19%|█▉        | 502/2600 [00:00<00:00, 5015.80it/s]
#  39%|███▊      | 1004/2600 [00:00<00:00, 4477.44it/s]
#  58%|█████▊    | 1512/2600 [00:00<00:00, 4732.75it/s]
#  76%|███████▋  | 1989/2600 [00:00<00:00, 4457.31it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4572.17it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  57%|█████▋    | 370/651 [00:00<00:00, 3695.00it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4248.93it/s]
# (tune_model pid=29284) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=29284)   warnings.warn('resource_tracker: There appear to be %d '
#  18%|█▊        | 472/2600 [00:00<00:00, 4716.70it/s]
#  36%|███▋      | 944/2600 [00:00<00:00, 4404.05it/s]
#  54%|█████▎    | 1392/2600 [00:00<00:00, 4433.91it/s]
#  71%|███████   | 1837/2600 [00:00<00:00, 4297.55it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4312.70it/s]
#  71%|███████   | 463/651 [00:00<00:00, 4620.48it/s]
# 100%|██████████| 651/651 [00:00<00:00, 3735.82it/s]
# (tune_model pid=29364) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=29364)   _log_deprecation_warning(
# (tune_model pid=29382) 2025-10-01 22:10:31.019 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
# (tune_model pid=29390) 2025-10-01 22:10:36.478 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#  18%|█▊        | 472/2600 [00:00<00:00, 4705.63it/s]
#  36%|███▋      | 943/2600 [00:00<00:00, 4286.51it/s]
#  77%|███████▋  | 1993/2600 [00:00<00:00, 4952.27it/s]
#  96%|█████████▌| 2492/2600 [00:00<00:00, 4582.95it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4638.70it/s]
# 100%|██████████| 651/651 [00:00<00:00, 3601.02it/s]
# (tune_model pid=29390) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.05 and num_layers=1
# (tune_model pid=29390)   warnings.warn(
# (tune_model pid=29376) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=29376)   _log_deprecation_warning(
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
# (tune_model pid=29390) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=29390)   _log_deprecation_warning(
# (tune_model pid=29282) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=29282)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=29418) 2025-10-01 22:10:50.021 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#
/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4638.76it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4625.58it/s]
# (tune_model pid=36799) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=36799)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=36859) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=36859)   _log_deprecation_warning(
# (tune_model pid=36872) 2025-10-03 13:38:21.943 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
# (tune_model pid=36916) 2025-10-03 13:38:29.068 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/651 [00:00<?, ?it/s]
# (tune_model pid=36800) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=36800)   warnings.warn('resource_tracker: There appear to be %d '
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  16%|█▌        | 409/2600 [00:00<00:00, 3953.14it/s]
#  36%|███▌      | 924/2600 [00:00<00:00, 4639.27it/s]
#  58%|█████▊    | 1507/2600 [00:00<00:00, 5176.61it/s]
#  78%|███████▊  | 2026/2600 [00:00<00:00, 4839.38it/s]
# (tune_model pid=36872) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=36872)   _log_deprecation_warning( [repeated 2x across cluster]
#  97%|█████████▋| 2514/2600 [00:00<00:00, 4199.18it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4422.87it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  65%|██████▌   | 425/651 [00:00<00:00, 4248.82it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4250.85it/s]
#  19%|█▊        | 486/2600 [00:00<00:00, 4836.31it/s]
#  40%|████      | 1053/2600 [00:00<00:00, 5315.09it/s]
#  61%|██████    | 1585/2600 [00:00<00:00, 4974.01it/s]
#  80%|████████  | 2085/2600 [00:00<00:00, 4860.40it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4703.19it/s]
# 100%|██████████| 651/651 [00:00<00:00, 5454.91it/s]
#  37%|███▋      | 964/2600 [00:00<00:00, 4853.42it/s]
#  56%|█████▌    | 1450/2600 [00:00<00:00, 4559.96it/s]
#  73%|███████▎  | 1908/2600 [00:00<00:00, 4297.94it/s]
#  92%|█████████▏| 2395/2600 [00:00<00:00, 4489.65it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4468.48it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4607.15it/s]
# (tune_model pid=36919) 2025-10-03 13:38:33.036 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures [repeated 2x across cluster]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 4x across cluster]
# (tune_model pid=36916) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=36916)   _log_deprecation_warning(
# (tune_model pid=36917) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=36917)   _log_deprecation_warning(
# (tune_model pid=36932) 2025-10-03 13:38:44.109 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  18%|█▊        | 469/2600 [00:00<00:00, 4680.21it/s]
#  36%|███▌      | 938/2600 [00:00<00:00, 4435.70it/s]
#  53%|█████▎    | 1383/2600 [00:00<00:00, 4260.12it/s]
#  70%|██████▉   | 1810/2600 [00:00<00:00, 3476.95it/s]
#  86%|████████▌ | 2232/2600 [00:00<00:00, 3701.91it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 3858.22it/s]
#   0%|          | 0/651 [00:00<?, ?it/s]
#  47%|████▋     | 307/651 [00:00<00:00, 3069.57it/s]
# 100%|██████████| 651/651 [00:00<00:00, 3329.09it/s]
# (tune_model pid=36843) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=36843)   _log_deprecation_warning(
# (tune_model pid=36859) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=36859)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=36919) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=36919)   _log_deprecation_warning(
# (tune_model pid=36916) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=36916)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=36932) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=36932)   _log_deprecation_warning(
# (tune_model pid=36917) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=36917)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=36919) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown [repeated 2x across cluster]
# (tune_model pid=36919)   warnings.warn('resource_tracker: There appear to be %d ' [repeated 2x across cluster]
# (tune_model pid=36843) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=36843)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=38535) 2025-10-03 14:35:50.435 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/2600 [00:00<?, ?it/s]
#  19%|█▉        | 498/2600 [00:00<00:00, 4975.22it/s]
#  40%|████      | 1040/2600 [00:00<00:00, 5228.97it/s]
#  60%|██████    | 1563/2600 [00:00<00:00, 5204.18it/s]
#  80%|████████  | 2084/2600 [00:00<00:00, 5174.92it/s]
# 100%|██████████| 2600/2600 [00:00<00:00,
/Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=50248)   _log_deprecation_warning( [repeated 2x across cluster]
#  22%|██▏       | 559/2600 [00:00<00:00, 5586.37it/s]
#  43%|████▎     | 1118/2600 [00:00<00:00, 4683.30it/s]
#  67%|██████▋   | 1731/2600 [00:00<00:00, 5279.70it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 5110.46it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4518.36it/s]
# (tune_model pid=50297) 2025-10-04 08:20:49.189 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures [repeated 2x across cluster]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 4x across cluster]
#  23%|██▎       | 604/2600 [00:00<00:00, 6039.03it/s]
# (tune_model pid=50286) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50286)   warnings.warn('resource_tracker: There appear to be %d '
#  46%|████▋     | 1208/2600 [00:00<00:00, 4742.65it/s]
#  70%|██████▉   | 1815/2600 [00:00<00:00, 5262.80it/s]
#  91%|█████████ | 2359/2600 [00:00<00:00, 4850.31it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4930.36it/s]
# 100%|██████████| 651/651 [00:00<00:00, 5008.54it/s]
# (tune_model pid=50286) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=50286)   _log_deprecation_warning(
#  40%|████      | 1040/2600 [00:00<00:00, 5240.07it/s]
#  60%|██████    | 1564/2600 [00:00<00:00, 4690.71it/s]
#  78%|███████▊  | 2040/2600 [00:00<00:00, 3924.80it/s]
#  98%|█████████▊| 2551/2600 [00:00<00:00, 4284.61it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4433.98it/s]
#  70%|███████   | 456/651 [00:00<00:00, 4544.69it/s]
# 100%|██████████| 651/651 [00:00<00:00, 4278.23it/s]
# (tune_model pid=50292) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=50292)   _log_deprecation_warning(
# (tune_model pid=50316) 2025-10-04 08:20:51.994 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 4x across cluster]
# (tune_model pid=50323) 2025-10-04 08:20:55.516 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
# (tune_model pid=50292) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50292)   warnings.warn('resource_tracker: There appear to be %d '
#  18%|█▊        | 479/2600 [00:00<00:00, 4338.21it/s]
#  36%|███▌      | 935/2600 [00:00<00:00, 4462.81it/s]
#  53%|█████▎    | 1382/2600 [00:00<00:00, 4343.54it/s]
#  70%|██████▉   | 1817/2600 [00:00<00:00, 4076.53it/s]
#  87%|████████▋ | 2252/2600 [00:00<00:00, 4018.86it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4249.27it/s]
# 100%|██████████| 651/651 [00:00<00:00, 6008.98it/s]
# (tune_model pid=50316) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=50316)   _log_deprecation_warning(
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
#  11%|█▏        | 293/2600 [00:00<00:00, 2928.33it/s]
#  23%|██▎       | 586/2600 [00:00<00:00, 2154.62it/s]
#  37%|███▋      | 962/2600 [00:00<00:00, 2658.04it/s]
# (tune_model pid=50326) 2025-10-04 08:20:59.948 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#  56%|█████▌    | 1443/2600 [00:00<00:00, 3394.23it/s]
#  74%|███████▍  | 1926/2600 [00:00<00:00, 3866.20it/s]
#  91%|█████████ | 2368/2600 [00:00<00:00, 4042.93it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 3370.15it/s]
#  57%|█████▋    | 373/651 [00:00<00:00, 3729.28it/s]
# 100%|██████████| 651/651 [00:00<00:00, 2915.79it/s]
# (tune_model pid=50284) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=50284)   _log_deprecation_warning(
# (tune_model pid=50297) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50297)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=50335) 2025-10-04 08:21:04.245 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#  17%|█▋        | 448/2600 [00:00<00:00, 4441.45it/s]
#  37%|███▋      | 954/2600 [00:00<00:00, 4792.57it/s]
#  56%|█████▌    | 1443/2600 [00:00<00:00, 4835.14it/s]
#  74%|███████▍  | 1927/2600 [00:00<00:00, 4440.92it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 4438.70it/s]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 4x across cluster]
# 100%|██████████| 651/651 [00:00<00:00, 5208.08it/s]
# (tune_model pid=50335) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/torch/nn/modules/rnn.py:123: UserWarning: dropout option adds dropout after all but last recurrent layer, so non-zero dropout expects num_layers greater than 1, but got dropout=0.1 and num_layers=1
# (tune_model pid=50335)   warnings.warn(
#  21%|██▏       | 554/2600 [00:00<00:00, 5538.41it/s]
#  43%|████▎     | 1108/2600 [00:00<00:00, 5445.48it/s]
#  64%|██████▎   | 1653/2600 [00:00<00:00, 4796.25it/s]
#  86%|████████▌ | 2226/2600 [00:00<00:00, 5134.61it/s]
# (tune_model pid=50256) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 3x across cluster]
# (tune_model pid=50256)   _log_deprecation_warning( [repeated 3x across cluster]
# 100%|██████████| 2600/2600 [00:00<00:00, 5056.63it/s]
#  82%|████████▏ | 536/651 [00:00<00:00, 5356.63it/s]
# 100%|██████████| 651/651 [00:00<00:00, 5367.57it/s]
# (tune_model pid=50326) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50326)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=50357) 2025-10-04 08:21:07.881 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
# (tune_model pid=50335) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50335)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=50363) 2025-10-04 08:21:11.459 | INFO     | mads_datasets.base:download_data:121 - Folder already exists at /Users/nickreinders/.cache/mads_datasets/gestures
#  11%|█         | 285/2600 [00:00<00:00, 2848.83it/s]
#  23%|██▎       | 602/2600 [00:00<00:00, 3035.44it/s]
#  40%|████      | 1046/2600 [00:00<00:00, 3642.43it/s]
#  55%|█████▍    | 1417/2600 [00:00<00:00, 3665.75it/s]
#  69%|██████▊   | 1784/2600 [00:00<00:00, 3454.49it/s]
#  87%|████████▋ | 2267/2600 [00:00<00:00, 3896.98it/s]
# 100%|██████████| 2600/2600 [00:00<00:00, 3730.63it/s]
# 100%|██████████| 651/651 [00:00<00:00, 3721.81it/s]
# (tune_model pid=50258) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454 [repeated 2x across cluster]
# (tune_model pid=50258)   _log_deprecation_warning( [repeated 2x across cluster]
#   0%|          | 0/651 [00:00<?, ?it/s] [repeated 2x across cluster]
# (tune_model pid=50357) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=50357)   _log_deprecation_warning(
# (tune_model pid=50323) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=50323)   _log_deprecation_warning(
# (tune_model pid=50363) /Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/.venv/lib/python3.11/site-packages/ray/train/_internal/session.py:772: RayDeprecationWarning: `ray.train.report` should be switched to `ray.tune.report` when running in a function passed to Ray Tune. This will be an error in the future. See this issue for more context: https://github.com/ray-project/ray/issues/49454
# (tune_model pid=50363)   _log_deprecation_warning(
# (tune_model pid=50363) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50363)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=50357) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50357)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=50248) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50248)   warnings.warn('resource_tracker: There appear to be %d '
# (tune_model pid=50258) /Users/nickreinders/.local/share/uv/python/cpython-3.11.9-macos-aarch64-none/lib/python3.11/multiprocessing/resource_tracker.py:254: UserWarning: resource_tracker: There appear to be 1 leaked semaphore objects to clean up at shutdown
# (tune_model pid=50258)   warnings.warn('resource_tracker: There appear to be %d '

# %%
def plot_contour(df, x, y, z, start=0.90, end=1.0, size=0.01):
    fig = go.Figure()

    fig.add_trace(
        go.Contour(
            z=df[z],
            x=df[x],
            y=df[y],
            contours=dict(
                coloring='heatmap',
                showlabels=True,  # show labels on contours
                start=start,       # start of the contour range
                end=end,          # end of the contour range
                size=size,
            ),
            colorscale="plasma",
            colorbar=dict(
                title='Accuracy'
            )
        )
    )

    fig.add_trace(
        go.Scatter(
            x=df[x],
            y=df[y],
            mode='markers',
            marker=dict(
                color='black',
                size=8,
                symbol='circle'
            ),
            customdata=df['accuracy'],  # Pass accuracy values for hover text
            hovertemplate=(
                'Hidden Size: %{x}<br>'
                'Number of Layers: %{y}<br>'
                'Accuracy: %{customdata:.4f}<extra></extra>'
            ),
            name='Data Points'
        )
    )

    fig.update_layout(
        title="Contour Plot",
        xaxis_title="Hidden Size",
        yaxis_title="Number of Layers",
        xaxis=dict(showgrid=False),  # Remove x-axis grid lines
        yaxis=dict(showgrid=False),
        plot_bgcolor='white',        # Set background color to white
        paper_bgcolor='white'
    )

    fig.show()

# %%
all_results = analysis.results_df

# %%
random = analysis.results_df
plot_contour(random, "config/hidden_size", "config/num_layers", "accuracy")

# %% [markdown]
# As you can see, the search space is sort of randomly sampled.
# Even though big parts are unexplored, it still looks like we find some hotspots.

# %%
best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["random"] = best

# %% [markdown]
# So, we searched the hyperparameter space. Problem is, these spaces potentially can get
# pretty big. Let's imagine you have 10 hyperparameters, and every hyperparameter has 5
# possible (relevant) values, you already have $5^{10}$ possible combinations, which is almost 10 million. Even if checking of every configuration would take just 1 second, it would take more than a 100 days to check them all...This
# space can grow out of control pretty fast.
#
# Lets look at the best results we found.

# %%
best
# Out:
# {'input_size': 3,
#  'output_size': 20,
#  'dropout': 0.05,
#  'epochs': 10,
#  'hidden_size': 293,
#  'num_layers': 3,
#  'tune_dir': PosixPath('/Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test'),
#  'accuracy': 0.996875}

# %%
columns = ["config/hidden_size", "config/num_layers", "accuracy"]
visualize.parallel_plot(analysis, columns)

# %% [markdown]
# Note how the mean scores are sort of randomly distributed. This is a direct
# effect of random guessing parameters.

# %% [markdown]
# # Grid search

# %% [markdown]
# We can do this more rigorous with a gridsearch.
# The upside of this technique is that you will test every configuration.
#
# A huge downside is the inefficiency. Also, you will run experiments with combinations that might be not very promising, but very slow, which is pretty inefficient.
#
#
# One way to handle this is to use doubling as a strategy to scan the range: 16, 32, ..., 512. This is a bit more efficient.
#
# Typically, this can be a good idea for a first scan, to get a rough idea of the space.
# After you have done this, you can narrow your searchspace, and do a more fine grained search zoomed in on areas that seem promising.

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.grid_search([16, 32, 64, 128, 256, 512]),
    "num_layers": tune.grid_search([2, 4, 8]),
    "tune_dir": tune_dir,
}

# %%
tic = time.time()

analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    stop={"training_iteration": MAX_EPOCHS},
    verbose=1,
)

timer["ray_grid"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["grid"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-10-03 13:42:24</td></tr>
# <tr><td>Running for: </td><td>00:04:33.30        </td></tr>
# <tr><td>Memory:      </td><td>11.6/16.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/10 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name            </th><th>status    </th><th>loc            </th><th style="text-align: right;">  hidden_size</th><th style="text-align: right;">  num_layers</th><th style="text-align: right;">  iter</th><th style="text-align: right;">  total time (s)</th><th style="text-align: right;">  valid_loss</th><th style="text-align: right;">  train_loss</th><th style="text-align: right;">  accuracy</th></tr>
# </thead>
# <tbody>
# <tr><td>tune_model_64d56_00000</td><td>TERMINATED</td><td>127.0.0.1:36794</td><td style="text-align: right;">           16</td><td style="text-align: right;">           2</td><td style="text-align: right;">    10</td><td style="text-align: right;">         14.0662</td><td style="text-align: right;">   1.60538  </td><td style="text-align: right;">   1.66011  </td><td style="text-align: right;">  0.395313</td></tr>
# <tr><td>tune_model_64d56_00001</td><td>TERMINATED</td><td>127.0.0.1:36797</td><td style="text-align: right;">           32</td><td style="text-align: right;">           2</td><td style="text-align: right;">    10</td><td style="text-align: right;
td><td style="text-align: right;">           4</td><td style="text-align: right;">    10</td><td style="text-align: right;">        168.872 </td><td style="text-align: right;">   0.134905 </td><td style="text-align: right;">   0.0211808</td><td style="text-align: right;">  0.9625  </td></tr>
# <tr><td>tune_model_64d56_00012</td><td>TERMINATED</td><td>127.0.0.1:36859</td><td style="text-align: right;">           16</td><td style="text-align: right;">           8</td><td style="text-align: right;">    10</td><td style="text-align: right;">         31.9353</td><td style="text-align: right;">   1.99805  </td><td style="text-align: right;">   1.98541  </td><td style="text-align: right;">  0.234375</td></tr>
# <tr><td>tune_model_64d56_00013</td><td>TERMINATED</td><td>127.0.0.1:36872</td><td style="text-align: right;">           32</td><td style="text-align: right;">           8</td><td style="text-align: right;">    10</td><td style="text-align: right;">         37.3983</td><td style="text-align: right;">   0.822557 </td><td style="text-align: right;">   0.916186 </td><td style="text-align: right;">  0.56875 </td></tr>
# <tr><td>tune_model_64d56_00014</td><td>TERMINATED</td><td>127.0.0.1:36916</td><td style="text-align: right;">           64</td><td style="text-align: right;">           8</td><td style="text-align: right;">    10</td><td style="text-align: right;">         48.9247</td><td style="text-align: right;">   0.731157 </td><td style="text-align: right;">   0.746723 </td><td style="text-align: right;">  0.642188</td></tr>
# <tr><td>tune_model_64d56_00015</td><td>TERMINATED</td><td>127.0.0.1:36917</td><td style="text-align: right;">          128</td><td style="text-align: right;">           8</td><td style="text-align: right;">    10</td><td style="text-align: right;">         76.4377</td><td style="text-align: right;">   0.426659 </td><td style="text-align: right;">   0.516354 </td><td style="text-align: right;">  0.826562</td></tr>
# <tr><td>tune_model_64d56_00016</td><td>TERMINATED</td><td>127.0.0.1:36919</td><td style="text-align: right;">          256</td><td style="text-align: right;">           8</td><td style="text-align:
# 2025-10-03 13:42:24,621	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-03_13-37-51' in 0.0074s.
# 2025-10-03 13:42:24,625	INFO tune.py:1041 -- Total run time: 273.35 seconds (273.30 seconds for the tuning loop).

# %%
import pandas as pd
all_results = pd.concat([all_results, analysis.results_df])

# %%
grid = analysis.results_df
plot_contour(grid, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %% [markdown]
# As you can see, we get a systematic scan, but large parts of the space are still unexplored, and we also explored parts that are really not very promising.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %% [markdown]
# # Bayes

# %% [markdown]
# Now, we improve the search algorithm with a bayesian optimization.
#
# Note that the bayesian search algorithm will only work with continuous parameters. This is a problem for the number of layers, which is a discrete parameter. I fixed this by simply casting the parameters to an integer inside the model, which is not very elegant but it works.

# %%
from ray.tune.search.bayesopt import BayesOptSearch

bayesopt = BayesOptSearch(metric="valid_loss", mode="min")


config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.uniform(16, 512),
    "num_layers": tune.uniform(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()

analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    search_alg=bayesopt,
    verbose=1,
)

timer["ray_bayes"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["bayes"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025-10-03 14:39:03</td></tr>
# <tr><td>Running for: </td><td>00:03:15.90        </td></tr>
# <tr><td>Memory:      </td><td>11.1/16.0 GiB      </td></tr>
# </tbody>
# </table>
#     </div>
#     <div class="vDivider"></div>
#     <div class="systemInfo">
#       <h3>System Info</h3>
#       Using FIFO scheduling algorithm.<br>Logical resource usage: 1.0/10 CPUs, 0/0 GPUs
#     </div>
#
#   </div>
#   <div class="hDivider"></div>
#   <div class="trialStatus">
#     <h3>Trial Status</h3>
#     <table>
# <thead>
# <tr><th>Trial name         </th><th>status    </th><th>lo
# 2025-10-03 14:37:54,648	INFO bayesopt_search.py:293 -- Skipping duplicated config: {'hidden_size': np.float64(229.49357578453206), 'num_layers': np.float64(1.5357464325395038)}.
# 2025-10-03 14:37:54,778	INFO bayesopt_search.py:293 -- Skipping duplicated config: {'hidden_size': np.float64(229.49357578453206), 'num_layers': np.float64(1.5357464325395038)}.
# 2025-10-03 14:39:03,994	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-03_14-35-48' in 0.0107s.
# 2025-10-03 14:39:03,997	INFO tune.py:1041 -- Total run time: 195.91 seconds (195.89 seconds for the tuning loop).

# %%
best
# Out:
# {'input_size': 3,
#  'output_size': 20,
#  'dropout': 0.1,
#  'epochs': 10,
#  'hidden_size': np.float64(271.2563060950412),
#  'num_layers': np.float64(3.173292899727462),
#  'tune_dir': PosixPath('/Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test'),
#  'accuracy': 0.9921875}

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
bayes = analysis.results_df
plot_contour(bayes, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %% [markdown]
# As you can see, bayes really focuses on the promising areas. It is much more efficient than random search, and also more efficient than grid search.
# We have set the `random_search_steps` to 5, this means that we will do 5 random searches first, to get a good initial idea of the space. As you can see, 5 is a bit low, because it might lead to premature converging to a local optimum. You can increase this number to get a better initial idea of the space, but you will also need to increase the number of iterations after the initial random scan.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %%
import pandas as pd

pd.DataFrame.from_dict(best_config, orient="index")
# Out:
#         input_size  output_size  dropout  epochs  hidden_size  num_layers  \
# random           3           20     0.05      10   293.000000    3.000000
# grid             3           20     0.10      10   512.000000    2.000000
# bayes            3           20     0.10      10   271.256306    3.173293
#
#                                                  tune_dir  accuracy
# random  /Users/nickreinders/Documents/Master_Applied_D...  0.996875
# grid    /Users/nickreinders/Documents/Master_Applied_D...  0.993750
# bayes   /Users/nickreinders/Documents/Master_Applied_D...  0.992188

# %% [markdown]
# # Hyperband
#
# Hyperband aborts runs early. Configs that are unpromising are abandoned before they complete.

# %%
from ray.tune.schedulers import AsyncHyperBandScheduler

scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration", grace_period=1, reduction_factor=3, max_t=MAX_EPOCHS
)

config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    scheduler=scheduler,
    verbose=1,
)

timer["ray_hyperband"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["hyperband"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025
td><td style="text-align: right;">           2</td><td style="text-align: right;">    10</td><td style="text-align: right;">        51.8585 </td><td style="text-align: right;">   0.0351043</td><td style="text-align: right;">  0.0223307 </td><td style="text-align: right;">  0.990625</td></tr>
# <tr><td>tune_model_d7031_00009</td><td>TERMINATED</td><td>127.0.0.1:41720</td><td style="text-align: right;">           44</td><td style="text-align: right;">           1</td><td style="text-align: right;">     1</td><td style="text-align: right;">         4.33257</td><td style="text-align: right;">   2.878    </td><td style="text-align: right;">  2.96383   </td><td style="text-align: right;">  0.123438</td></tr>
# <tr><td>tune_model_d7031_00010</td><td>TERMINATED</td><td>127.0.0.1:41739</td><td style="text-align: right;">          300</td><td style="text-align: right;">           6</td><td style="text-align: right;">     3</td><td style="text-align: right;">        70.5814 </td><td style="text-align: right;">   1.18697  </td><td style="text-align: right;">  1.35403   </td><td style="text-align: right;">  0.504687</td></tr>
# <tr><td>tune_model_d7031_00011</td><td>TERMINATED</td><td>127.0.0.1:41758</td><td style="text-align: right;">          323</td><td style="text-align: right;">           4</td><td style="text-align: right;">     9</td><td style="text-align: right;">       131.082  </td><td style="text-align: right;">   0.0673879</td><td style="text-align: right;">  0.0305242 </td><td style="text-align: right;">  0.979688</td></tr>
# <tr><td>tune_model_d7031_00012</td><td>TERMINATED</td><td>127.0.0.1:41783</td><td style="text-align: right;">          288</td><td style="text-align: right;">           6</td><td style="text-align: right;">     1</td><td style="text-align: right;">        25.6635 </td><td style="text-align: right;">   1.92283  </td><td style="text-align: right;">  2.32405   </td><td style="text-align: right;">  0.273438</td></tr>
# <tr><td>tune_model_d7031_00013</td><td>TERMINATED</td><td>127.0.0.1:41823</td><td style="text-align: right;">          242</td><td style="text-align: right;">           2</td><td style="text-align: right;">     1</td><td style="text-align: right;">        10.2434 </td><td style="text-align: right;">   2.02774  </td><td style="text-align: right;">  2.43911   </td><td style="text-align: right;">  0.307812</td></tr>
# <tr><td>tune_model_d7031_00014</td><td>TERMINATED</td><td>127.0.0.1:41822</td><td style="text-align: right;">          293</td><td style="text-align: right;">           2</td><td style="text-align: right;">     1</td><td style="text-align: right;">        12.8408 </td><td style="text-align: right;">   2.09457  </td><td style="text-align: right;">  2.37576   </td><td style="text-align: right;">  0.225   </td></tr>
# <tr><td>tune_model_d7031_00015</td><td>TERMINATED</td><td>127.0.0.1:41857</td><td style="text-align: right;">          338</td><td style="text-align: right;">           2</td><td style="text-align: right;">    10</td><td style="text-align: right;">        72.7247 </td><td style="text-align: right;">   0.0297775</td><td style="text-align: right;">  0.0133327 </td><td style="text-align: right;">  0.995313</td></tr>
# <tr><td>tune_model_d7031_00016</td><td>TERMINATED</td><td>127.0.0.1:41859</td><td
# 2025-10-03 20:10:32,615	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-03_20-07-35' in 0.0101s.
# 2025-10-03 20:10:32,619	INFO tune.py:1041 -- Total run time: 176.94 seconds (176.90 seconds for the tuning loop).

# %% [markdown]
# If you study the iter column, you will see that some runs have been stopped early. This is exactly the point of hyperband: it tries to allocate resources to the most promising configurations.
#
# The downside of this, is that if you try to get a good view of the space, you get distorted results because comparing a model that has trained just 1 or 3 epochs with a model that has trained 100 epochs is not very fair...

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
hyperband = analysis.results_df
plot_contour(hyperband, "config/hidden_size", "config/num_layers", "accuracy", start=0.7)

# %%
visualize.parallel_plot(analysis, columns)

# %% [markdown]
# But note that it is faster! This means you could do more runs in the same time, which might be a good tradeoff!
# Typically you will get better results if you scan the searchspace better by doing more runs, aborting the ones that are not promising and going on with the ones that seem to yield good results.

# %%
visualize.plot_timers(timer)

# %%
pd.DataFrame.from_dict(best_config, orient="index")
# Out:
#            input_size  output_size  dropout  epochs  hidden_size  num_layers  \
# random              3           20     0.05      10   293.000000    3.000000
# grid                3           20     0.10      10   512.000000    2.000000
# bayes               3           20     0.10      10   271.256306    3.173293
# hyperband           3           20     0.10      10   466.000000    4.000000
#
#                                                     tune_dir  accuracy
# random     /Users/nickreinders/Documents/Master_Applied_D...  0.996875
# grid       /Users/nickreinders/Documents/Master_Applied_D...  0.993750
# bayes      /Users/nickreinders/Documents/Master_Applied_D...  0.992188
# hyperband  /Users/nickreinders/Documents/Master_Applied_D...  0.993750

# %% [markdown]
# # Hyperbayes

# %% [markdown]
# It is possible to combine Hyperband with Bayesian optimization, implemented as `TuneBOHB` in ray.
# However, `TuneBOHB` in ray is dependent on `hpbandster`, which is not maintained anymore.
# Unfortunately, a dependency of `hpbandster` is `netifaces`, which is also not maintained anymore.
# While `netifaces` does work on some hardware, it fails to build on some other hardware, which is a problem.
#
# To still use BOHB type algoritms, I am planning to implement either SMAC3 or BEHB in the future.

# %% [markdown]
# # HyperOpt
# HyperOpt provides gradient/derivative-free optimization. They implemented TPE, which stands for Tree-structured Parzen Estimator. This is a bayesian optimization algorithm that uses a tree to model the distribution of the objective function. The main advantage is that TPE also works with discrete parameters and conditional search spaces which is a problem for the bayesian optimization.
#
# For example, you could do things like this:
# ```python
# conditional_space = {
#     "activation": hp.choice(
#         "activation",
#         [
#             {"activation": "relu", "mult": hp.uniform("mult", 1, 2)},
#             {"activation": "tanh"},
#         ],
#     ),
# }
# ```
#
# Where you have a discrete parameter `activation` that has a conditional parameter `mult`. This means that if you choose `relu`, you also need to set `mult`, but if you choose `tanh`, you do not need to set `mult`. See [documentation of ray](https://docs.ray.io/en/latest/tune/examples/hyperopt_example.html) for more details.

# %%
from ray.tune.search.hyperopt import HyperOptSearch
search = HyperOptSearch()

scheduler = AsyncHyperBandScheduler(
    time_attr="training_iteration", grace_period=1, reduction_factor=3, max_t=MAX_EPOCHS
)

# %%
config = {
    "input_size": 3,
    "output_size": 20,
    "dropout": 0.1,
    "epochs": MAX_EPOCHS,
    "hidden_size": tune.randint(16, 512),
    "num_layers": tune.randint(1, 8),
    "tune_dir": tune_dir,
}

tic = time.time()
analysis = tune.run(
    tune_model,
    config=config,
    metric="valid_loss",
    mode="min",
    storage_path=str(tune_dir),
    num_samples=N_EXPERIMENTS,
    stop={"training_iteration": MAX_EPOCHS},
    search_alg=search,
    scheduler=scheduler,
    verbose=1,
)

timer["ray_hyperopt"] = time.time() - tic

best = analysis.get_best_config()
best["accuracy"] = analysis.best_result["accuracy"]
best_config["hyperopt"] = best
# Out:
# <div class="tuneStatus">
#   <div style="display: flex;flex-direction: row">
#     <div style="display: flex;flex-direction: column;">
#       <h3>Tune Status</h3>
#       <table>
# <tbody>
# <tr><td>Current time:</td><td>2025
td><td style="text-align: right;">      0.1</td><td style="text-align: right;">      10</td><td style="text-align: right;">          496</td><td style="text-align: right;">           3</td><td style="text-align: right;">           3</td><td style="text-align: right;">           20</td><td>/Users/nickrein_0a60</td><td style="text-align: right;">    10</td><td style="text-align: right;">       194.569  </td><td style="text-align: right;">   0.0709988</td><td style="text-align: right;">   0.0152585</td><td style="text-align: right;">  0.9875  </td></tr>
# <tr><td>tune_model_3882e64b</td><td>TERMINATED</td><td>127.0.0.1:50286</td><td style="text-align: right;">      0.1</td><td style="text-align: right;">      10</td><td style="text-align: right;">          166</td><td style="text-align: right;">           3</td><td style="text-align: right;">           3</td><td style="text-align: right;">           20</td><td>/Users/nickrein_0a60</td><td style="text-align: right;">     1</td><td style="text-align: right;">         7.5864 </td><td style="text-align: right;">   2.20865  </td><td style="text-align: right;">   2.44388  </td><td style="text-align: right;">  0.1875  </td></tr>
# <tr><td>tune_model_2c76ecc1</td><td>TERMINATED</td><td>127.0.0.1:50292</td><td style="text-align: right;">      0.1</td><td style="text-align: right;">      10</td><td style="text-align: right;">          133</td><td style="text-align: right;">
# 2025-10-04 08:20:30,116	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:20:35,372	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:20:40,799	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:20:49,515	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:20:54,219	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:20:56,784	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:21:01,052	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:21:03,791	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:21:05,161	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:21:11,258	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:22:14,015	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:22:31,602	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:23:02,727	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:23:07,118	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:23:35,438	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:23:51,044	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:23:54,010	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:24:25,844	INFO tensorboardx.py:308 -- Removed the following hyperparameter values when logging to tensorboard: {'tune_dir': ('__ref_ph', 'b1421250')}
# 2025-10-04 08:24:25,853	INFO tune.py:1009 -- Wrote the latest version of all result files and experiment state to '/Users/nickreinders/Documents/Master_Applied_Data_Science_deeltijd_HAN/Deployment/Raoul_repo/MADS-MachineLearning-course/notebooks/4_tuning_networks/logs/test/tune_model_2025-10-04_08-20-22' in 0.0078s.
# 2025-10-04 08:24:25,857	INFO tune.py:1041 -- Total run time: 243.23 seconds (243.20 seconds for the tuning loop).

# %%
all_results = pd.concat([all_results, analysis.results_df])

# %%
hyperbayes = analysis.results_df
plot_contour(hyperbayes, "config/hidden_size", "config/num_layers", "accuracy", start=0.3, size=0.05)

# %% [markdown]
# This model combines bayesian optimization with hyperband. This is a good idea, because it combines the efficiency of bayesian optimization with the speed of hyperband.

# %%
visualize.parallel_plot(analysis, columns)

# %%
visualize.plot_timers(timer)

# %%
pd.DataFrame.from_dict(best_config, orient="index")
# Out:
#            input_size  output_size  dropout  epochs  hidden_size  num_layers  \
# random              3           20     0.05      10   293.000000    3.000000
# grid                3           20     0.10      10   512.000000    2.000000
# bayes               3           20     0.10      10   271.256306    3.173293
# hyperband           3           20     0.10      10   466.000000    4.000000
# hyperopt            3           20     0.10      10   388.000000    3.000000
#
#                                                     tune_dir  accuracy
# random     /Users/nickreinders/Documents/Master_Applied_D...  0.996875
# grid       /Users/nickreinders/Documents/Master_Applied_D...  0.993750
# bayes      /Users/nickreinders/Documents/Master_Applied_D...  0.992188
# hyperband  /Users/nickreinders/Documents/Master_Applied_D...  0.993750
# hyperopt   /Users/nickreinders/Documents/Master_Applied_D...  0.987500

# %%
contour = all_results[all_results["training_iteration"] == MAX_EPOCHS]
plot_contour(contour, "config/hidden_size", "config/num_layers", "accuracy", start=0.8)

# %%
stop = time.time() - start
print(stop)
# Out:
# 209902.87967514992

# %%
if DELETE:
    import shutil
    shutil.rmtree(tune_dir)
